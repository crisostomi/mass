# %%
from datasets import load_dataset
from mass import PROJECT_ROOT

data_files = {
    'trainvaltest': str(PROJECT_ROOT / "data/CUB-200-2011/CUB_200_2011/images/**"),
}

# %%
data_files
# Out:
# {'trainvaltest': '/media/donato/Extra-storage/Code/model-merging/mass/data/CUB-200-2011/CUB_200_2011/images/**'}

# %%
dataset = load_dataset(
    path="imagefolder",
    data_files=data_files,
)
# Out:
# ...
# Generating trainvaltest split: 11788 examples [00:00, 31944.87 examples/s]
